# %%
#Importamos las librerías a usar
import warnings
import pandas as pd
from datetime import datetime
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')

from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler
import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
#Cargamos los conjuntos de datos
Boya7_30 = pd.read_csv('../Fase_2/Paso 4/Boya7_30_conduc_train.csv', sep=",", decimal=".")
Boya7_30['Date'] = pd.to_datetime(Boya7_30['Date'],format="%d/%m/%Y").astype(np.int64) // 10 ** 9
Boya7_30_train = Boya7_30[0:56]
Boya7_45 = pd.read_csv('../Fase_2/Paso 4/Boya7_45_conduc_test.csv', sep=",", decimal=".")
Boya7_45['Date'] = pd.to_datetime(Boya7_45['Date'],format="%d/%m/%Y").astype(np.int64) // 10 ** 9
Boya7_45_test = Boya7_45[50:71]

# %%
EPOCHS = 40
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(1, input_shape=(1,),activation='tanh'))
    #model.add(Flatten()) No se puede usar porque solo hay un input
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mean_squared_error"])
    model.summary()
    return model

# %%
from sklearn.externals import joblib
#Cuarto escenario
scaler = MinMaxScaler(feature_range=(-1, 1))
train = Boya7_30_train.values
test = Boya7_45_test.values
full = np.append(train,test,axis=0)
full = full.astype(np.float64)
full[:,1] = scaler.fit_transform(full[:,1].reshape(-1,1)).reshape(1,-1)
train = full[0:56]
test = full[56:76]

joblib.dump(scaler, "escala_escenario_4.scale") 
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]

# %%
model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=7)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From I:\Conda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 56 samples, validate on 20 samples
# Epoch 1/40
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1693 - mean_squared_error: 1.4840 - val_loss: 0.4414 - val_mean_squared_error: 0.2939
# Epoch 2/40
# 56/56 [==============================] - 0s 463us/step - loss: 1.1641 - mean_squared_error: 1.4717 - val_loss: 0.4395 - val_mean_squared_error: 0.2902
# Epoch 3/40
# 56/56 [==============================] - 0s 641us/step - loss: 1.1587 - mean_squared_error: 1.4594 - val_loss: 0.4378 - val_mean_squared_error: 0.2864
# Epoch 4/40
# 56/56 [==============================] - 0s 748us/step - loss: 1.1531 - mean_squared_error: 1.4462 - val_loss: 0.4361 - val_mean_squared_error: 0.2825
# Epoch 5/40
# 56/56 [==============================] - 0s 997us/step - loss: 1.1473 - mean_squared_error: 1.4330 - val_loss: 0.4343 - val_mean_squared_error: 0.2786
# Epoch 6/40
# 56/56 [==============================] - 0s 962us/step - loss: 1.1412 - mean_squared_error: 1.4192 - val_loss: 0.4324 - val_mean_squared_error: 0.2745
# Epoch 7/40
# 56/56 [==============================] - 0s 3ms/step - loss: 1.1350 - mean_squared_error: 1.4051 - val_loss: 0.4305 - val_mean_squared_error: 0.2705
# Epoch 8/40
# 56/56 [==============================] - 0s 659us/step - loss: 1.1285 - mean_squared_error: 1.3903 - val_loss: 0.4285 - val_mean_squared_error: 0.2663
# Epoch 9/40
# 56/56 [==============================] - 0s 588us/step - loss: 1.1217 - mean_squared_error: 1.3751 - val_loss: 0.4265 - val_mean_squared_error: 0.2621
# Epoch 10/40
# 56/56 [==============================] - 0s 801us/step - loss: 1.1147 - mean_squared_error: 1.3591 - val_loss: 0.4243 - val_mean_squared_error: 0.2577
# Epoch 11/40
# 56/56 [==============================] - 0s 570us/step - loss: 1.1074 - mean_squared_error: 1.3432 - val_loss: 0.4221 - val_mean_squared_error: 0.2534
# Epoch 12/40
# 56/56 [==============================] - 0s 1ms/step - loss: 1.0998 - mean_squared_error: 1.3259 - val_loss: 0.4197 - val_mean_squared_error: 0.2489
# Epoch 13/40
# 56/56 [==============================] - 0s 2ms/step - loss: 1.0918 - mean_squared_error: 1.3089 - val_loss: 0.4173 - val_mean_squared_error: 0.2445
# Epoch 14/40
# 56/56 [==============================] - 0s 1ms/step - loss: 1.0836 - mean_squared_error: 1.2905 - val_loss: 0.4148 - val_mean_squared_error: 0.2400
# Epoch 15/40
# 56/56 [==============================] - 0s 766us/step - loss: 1.0751 - mean_squared_error: 1.2728 - val_loss: 0.4122 - val_mean_squared_error: 0.2354
# Epoch 16/40
# 56/56 [==============================] - 0s 481us/step - loss: 1.0662 - mean_squared_error: 1.2538 - val_loss: 0.4094 - val_mean_squared_error: 0.2309
# Epoch 17/40
# 56/56 [==============================] - 0s 748us/step - loss: 1.0570 - mean_squared_error: 1.2342 - val_loss: 0.4066 - val_mean_squared_error: 0.2263
# Epoch 18/40
# 56/56 [==============================] - 0s 1ms/step - loss: 1.0474 - mean_squared_error: 1.2140 - val_loss: 0.4037 - val_mean_squared_error: 0.2218
# Epoch 19/40
# 56/56 [==============================] - 0s 819us/step - loss: 1.0375 - mean_squared_error: 1.1933 - val_loss: 0.4006 - val_mean_squared_error: 0.2173
# Epoch 20/40
# 56/56 [==============================] - 0s 499us/step - loss: 1.0272 - mean_squared_error: 1.1721 - val_loss: 0.3975 - val_mean_squared_error: 0.2128
# Epoch 21/40
# 56/56 [==============================] - 0s 552us/step - loss: 1.0164 - mean_squared_error: 1.1500 - val_loss: 0.3942 - val_mean_squared_error: 0.2084
# Epoch 22/40
# 56/56 [==============================] - 0s 588us/step - loss: 1.0053 - mean_squared_error: 1.1279 - val_loss: 0.3908 - val_mean_squared_error: 0.2041
# Epoch 23/40
# 56/56 [==============================] - 0s 695us/step - loss: 0.9938 - mean_squared_error: 1.1040 - val_loss: 0.3884 - val_mean_squared_error: 0.1999
# Epoch 24/40
# 56/56 [==============================] - 0s 534us/step - loss: 0.9819 - mean_squared_error: 1.0806 - val_loss: 0.3860 - val_mean_squared_error: 0.1958
# Epoch 25/40
# 56/56 [==============================] - 0s 784us/step - loss: 0.9695 - mean_squared_error: 1.0568 - val_loss: 0.3835 - val_mean_squared_error: 0.1919
# Epoch 26/40
# 56/56 [==============================] - 0s 962us/step - loss: 0.9567 - mean_squared_error: 1.0320 - val_loss: 0.3809 - val_mean_squared_error: 0.1883
# Epoch 27/40
# 56/56 [==============================] - 0s 926us/step - loss: 0.9434 - mean_squared_error: 1.0065 - val_loss: 0.3782 - val_mean_squared_error: 0.1848
# Epoch 28/40
# 56/56 [==============================] - 0s 552us/step - loss: 0.9297 - mean_squared_error: 0.9813 - val_loss: 0.3754 - val_mean_squared_error: 0.1816
# Epoch 29/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.9156 - mean_squared_error: 0.9549 - val_loss: 0.3725 - val_mean_squared_error: 0.1787
# Epoch 30/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.9010 - mean_squared_error: 0.9290 - val_loss: 0.3695 - val_mean_squared_error: 0.1762
# Epoch 31/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.8859 - mean_squared_error: 0.9013 - val_loss: 0.3664 - val_mean_squared_error: 0.1740
# Epoch 32/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.8703 - mean_squared_error: 0.8743 - val_loss: 0.3658 - val_mean_squared_error: 0.1723
# Epoch 33/40
# 56/56 [==============================] - 0s 588us/step - loss: 0.8544 - mean_squared_error: 0.8474 - val_loss: 0.3658 - val_mean_squared_error: 0.1710
# Epoch 34/40
# 56/56 [==============================] - 0s 570us/step - loss: 0.8379 - mean_squared_error: 0.8192 - val_loss: 0.3658 - val_mean_squared_error: 0.1703
# Epoch 35/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.8210 - mean_squared_error: 0.7899 - val_loss: 0.3658 - val_mean_squared_error: 0.1701
# Epoch 36/40
# 56/56 [==============================] - 0s 534us/step - loss: 0.8037 - mean_squared_error: 0.7616 - val_loss: 0.3658 - val_mean_squared_error: 0.1705
# Epoch 37/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.7859 - mean_squared_error: 0.7336 - val_loss: 0.3658 - val_mean_squared_error: 0.1716
# Epoch 38/40
# 56/56 [==============================] - 0s 605us/step - loss: 0.7679 - mean_squared_error: 0.7071 - val_loss: 0.3658 - val_mean_squared_error: 0.1734
# Epoch 39/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.7504 - mean_squared_error: 0.6790 - val_loss: 0.3675 - val_mean_squared_error: 0.1758
# Epoch 40/40
# 56/56 [==============================] - 0s 1ms/step - loss: 0.7323 - mean_squared_error: 0.6507 - val_loss: 0.3694 - val_mean_squared_error: 0.1790

# %%
results=model.predict(x_val)
def sacarResultados(results):
    return [x[0] for x in results]
resultados = sacarResultados(results)
validacion = pd.DataFrame({"reales":y_val,"prediccion":resultados})
validacion['indice'] = range(0,20)
#validacion.plot.scatter(x="indice)
ax1 = validacion.plot(kind="scatter",x="indice",y="reales", color="g",label="Reales")
validacion.plot(kind="scatter",x="indice",y="prediccion", ax=ax1, color="r",label="Predicciones")
plt.title('validate')
# Out:
# Text(0.5, 1.0, 'validate')

# %%
validate_loss = pd.DataFrame({"loss":history.history['loss'],"val_loss":history.history['val_loss']})
validate_loss.plot()
plt.title("Validate loss")
# Out:
# Text(0.5, 1.0, 'Validate loss')

# %%
compara = pd.DataFrame(np.array([y_val, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = abs(compara2['real'] - compara2['prediccion'])
compara2.head()
# Out:
#        real  prediccion  diferencia
# 0  0.105083    0.089658    0.015425
# 1  0.101208    0.089658    0.011550
# 2  0.095000    0.089658    0.005342
# 3  0.089833    0.089658    0.000175
# 4  0.092542    0.089658    0.002883

# %%
compara2.describe()
# Out:
#             real    prediccion  diferencia
# count  20.000000  2.000000e+01   20.000000
# mean    0.087196  8.965821e-02    0.009666
# std     0.011072  1.423831e-17    0.005535
# min     0.073292  8.965821e-02    0.000175
# 25%     0.075125  8.965821e-02    0.004931
# 50%     0.087208  8.965821e-02    0.010800
# 75%     0.095885  8.965821e-02    0.015033
# max     0.105083  8.965821e-02    0.016367

# %%
comparacion_predicciones = pd.DataFrame({"real":compara2['real'],"prediccion":compara2['prediccion']})
comparacion_predicciones.plot()
plt.title("Comparación predicciones")
# Out:
# Text(0.5, 1.0, 'Comparación predicciones')

# %%
plt.title('Accuracy')
plt.plot(history.history['mean_squared_error'])
plt.show()

# %%
model.save('escenario_4.h5')
