# %%
#Importamos las librerías a usar
import warnings
import pandas as pd
from datetime import datetime
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('fast')

from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.preprocessing import MinMaxScaler
import keras
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
#Cargamos los conjuntos de datos
Boya7_00 = pd.read_csv('../Fase_2/Paso 4/Boya7_00_conduc_train.csv', sep=",", decimal=".")
Boya7_00['Date'] = pd.to_datetime(Boya7_00['Date'],format="%d/%m/%Y").astype(np.int64) // 10 ** 9
Boya7_00_train = Boya7_00[0:56]
Boya7_15 = pd.read_csv('../Fase_2/Paso 4/Boya7_15_conduc_test.csv', sep=",", decimal=".")
Boya7_15['Date'] = pd.to_datetime(Boya7_15['Date'],format="%d/%m/%Y").astype(np.int64) // 10 ** 9
Boya7_15_test = Boya7_00[50:71]

# %%
EPOCHS = 40
def crear_modeloFF():
    model = Sequential() 
    model.add(Dense(1, input_shape=(1,),activation='tanh'))
    #model.add(Flatten()) No se puede usar porque solo hay un input
    model.add(Dense(1, activation='tanh'))
    model.compile(loss='mean_absolute_error',optimizer='Adam',metrics=["mean_squared_error"])
    model.summary()
    return model

# %%
from sklearn.externals import joblib

#Tercer escenario
scaler = MinMaxScaler(feature_range=(-1, 1))
train = Boya7_00_train.values
test = Boya7_15_test.values
full = np.append(train,test,axis=0)
full = full.astype(np.float64)
full[:,1] = scaler.fit_transform(full[:,1].reshape(-1,1)).reshape(1,-1)
train = full[0:56]
test = full[56:76]

joblib.dump(scaler, "escala_escenario_3.scale") 
x_train, y_train = train[:, :-1], train[:, -1]
x_val, y_val = test[:, :-1], test[:, -1]

# %%
model = crear_modeloFF()

history=model.fit(x_train,y_train,epochs=EPOCHS,validation_data=(x_val,y_val),batch_size=7)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From I:\Conda\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 56 samples, validate on 20 samples
# Epoch 1/40
# 56/56 [==============================] - 0s 5ms/step - loss: 1.1153 - mean_squared_error: 1.3592 - val_loss: 0.4144 - val_mean_squared_error: 0.2489
# Epoch 2/40
# 56/56 [==============================] - 0s 428us/step - loss: 1.1093 - mean_squared_error: 1.3461 - val_loss: 0.4126 - val_mean_squared_error: 0.2452
# Epoch 3/40
# 56/56 [==============================] - 0s 410us/step - loss: 1.1029 - mean_squared_error: 1.3318 - val_loss: 0.4106 - val_mean_squared_error: 0.2415
# Epoch 4/40
# 56/56 [==============================] - 0s 499us/step - loss: 1.0963 - mean_squared_error: 1.3174 - val_loss: 0.4086 - val_mean_squared_error: 0.2378
# Epoch 5/40
# 56/56 [==============================] - 0s 445us/step - loss: 1.0894 - mean_squared_error: 1.3026 - val_loss: 0.4065 - val_mean_squared_error: 0.2340
# Epoch 6/40
# 56/56 [==============================] - 0s 427us/step - loss: 1.0823 - mean_squared_error: 1.2867 - val_loss: 0.4043 - val_mean_squared_error: 0.2302
# Epoch 7/40
# 56/56 [==============================] - 0s 445us/step - loss: 1.0750 - mean_squared_error: 1.2709 - val_loss: 0.4021 - val_mean_squared_error: 0.2264
# Epoch 8/40
# 56/56 [==============================] - 0s 481us/step - loss: 1.0674 - mean_squared_error: 1.2545 - val_loss: 0.3997 - val_mean_squared_error: 0.2225
# Epoch 9/40
# 56/56 [==============================] - 0s 623us/step - loss: 1.0595 - mean_squared_error: 1.2378 - val_loss: 0.3973 - val_mean_squared_error: 0.2187
# Epoch 10/40
# 56/56 [==============================] - 0s 552us/step - loss: 1.0513 - mean_squared_error: 1.2211 - val_loss: 0.3948 - val_mean_squared_error: 0.2148
# Epoch 11/40
# 56/56 [==============================] - 0s 552us/step - loss: 1.0428 - mean_squared_error: 1.2030 - val_loss: 0.3922 - val_mean_squared_error: 0.2109
# Epoch 12/40
# 56/56 [==============================] - 0s 516us/step - loss: 1.0340 - mean_squared_error: 1.1847 - val_loss: 0.3895 - val_mean_squared_error: 0.2071
# Epoch 13/40
# 56/56 [==============================] - 0s 606us/step - loss: 1.0250 - mean_squared_error: 1.1666 - val_loss: 0.3868 - val_mean_squared_error: 0.2033
# Epoch 14/40
# 56/56 [==============================] - 0s 659us/step - loss: 1.0155 - mean_squared_error: 1.1470 - val_loss: 0.3845 - val_mean_squared_error: 0.1995
# Epoch 15/40
# 56/56 [==============================] - 0s 481us/step - loss: 1.0057 - mean_squared_error: 1.1270 - val_loss: 0.3825 - val_mean_squared_error: 0.1958
# Epoch 16/40
# 56/56 [==============================] - 0s 534us/step - loss: 0.9956 - mean_squared_error: 1.1066 - val_loss: 0.3805 - val_mean_squared_error: 0.1922
# Epoch 17/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.9851 - mean_squared_error: 1.0859 - val_loss: 0.3783 - val_mean_squared_error: 0.1886
# Epoch 18/40
# 56/56 [==============================] - 0s 1ms/step - loss: 0.9743 - mean_squared_error: 1.0645 - val_loss: 0.3761 - val_mean_squared_error: 0.1852
# Epoch 19/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.9630 - mean_squared_error: 1.0430 - val_loss: 0.3738 - val_mean_squared_error: 0.1819
# Epoch 20/40
# 56/56 [==============================] - 0s 606us/step - loss: 0.9514 - mean_squared_error: 1.0212 - val_loss: 0.3714 - val_mean_squared_error: 0.1788
# Epoch 21/40
# 56/56 [==============================] - 0s 499us/step - loss: 0.9394 - mean_squared_error: 0.9976 - val_loss: 0.3690 - val_mean_squared_error: 0.1759
# Epoch 22/40
# 56/56 [==============================] - 0s 534us/step - loss: 0.9269 - mean_squared_error: 0.9748 - val_loss: 0.3665 - val_mean_squared_error: 0.1732
# Epoch 23/40
# 56/56 [==============================] - 0s 499us/step - loss: 0.9141 - mean_squared_error: 0.9514 - val_loss: 0.3640 - val_mean_squared_error: 0.1707
# Epoch 24/40
# 56/56 [==============================] - 0s 463us/step - loss: 0.9008 - mean_squared_error: 0.9272 - val_loss: 0.3626 - val_mean_squared_error: 0.1685
# Epoch 25/40
# 56/56 [==============================] - 0s 677us/step - loss: 0.8872 - mean_squared_error: 0.9028 - val_loss: 0.3613 - val_mean_squared_error: 0.1666
# Epoch 26/40
# 56/56 [==============================] - 0s 641us/step - loss: 0.8731 - mean_squared_error: 0.8776 - val_loss: 0.3598 - val_mean_squared_error: 0.1651
# Epoch 27/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.8586 - mean_squared_error: 0.8528 - val_loss: 0.3583 - val_mean_squared_error: 0.1640
# Epoch 28/40
# 56/56 [==============================] - 0s 570us/step - loss: 0.8436 - mean_squared_error: 0.8270 - val_loss: 0.3568 - val_mean_squared_error: 0.1633
# Epoch 29/40
# 56/56 [==============================] - 0s 588us/step - loss: 0.8283 - mean_squared_error: 0.8011 - val_loss: 0.3553 - val_mean_squared_error: 0.1630
# Epoch 30/40
# 56/56 [==============================] - 0s 534us/step - loss: 0.8125 - mean_squared_error: 0.7765 - val_loss: 0.3544 - val_mean_squared_error: 0.1632
# Epoch 31/40
# 56/56 [==============================] - 0s 570us/step - loss: 0.7963 - mean_squared_error: 0.7495 - val_loss: 0.3544 - val_mean_squared_error: 0.1640
# Epoch 32/40
# 56/56 [==============================] - 0s 516us/step - loss: 0.7797 - mean_squared_error: 0.7243 - val_loss: 0.3556 - val_mean_squared_error: 0.1654
# Epoch 33/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.7627 - mean_squared_error: 0.6972 - val_loss: 0.3574 - val_mean_squared_error: 0.1674
# Epoch 34/40
# 56/56 [==============================] - 0s 552us/step - loss: 0.7453 - mean_squared_error: 0.6705 - val_loss: 0.3591 - val_mean_squared_error: 0.1700
# Epoch 35/40
# 56/56 [==============================] - 0s 499us/step - loss: 0.7275 - mean_squared_error: 0.6455 - val_loss: 0.3609 - val_mean_squared_error: 0.1733
# Epoch 36/40
# 56/56 [==============================] - 0s 535us/step - loss: 0.7096 - mean_squared_error: 0.6187 - val_loss: 0.3645 - val_mean_squared_error: 0.1773
# Epoch 37/40
# 56/56 [==============================] - 0s 552us/step - loss: 0.6923 - mean_squared_error: 0.5932 - val_loss: 0.3682 - val_mean_squared_error: 0.1821
# Epoch 38/40
# 56/56 [==============================] - 0s 517us/step - loss: 0.6742 - mean_squared_error: 0.5675 - val_loss: 0.3719 - val_mean_squared_error: 0.1875
# Epoch 39/40
# 56/56 [==============================] - 0s 481us/step - loss: 0.6564 - mean_squared_error: 0.5436 - val_loss: 0.3756 - val_mean_squared_error: 0.1937
# Epoch 40/40
# 56/56 [==============================] - 0s 499us/step - loss: 0.6381 - mean_squared_error: 0.5195 - val_loss: 0.3794 - val_mean_squared_error: 0.2007

# %%
results=model.predict(x_val)
def sacarResultados(results):
    return [x[0] for x in results]
resultados = sacarResultados(results)
validacion = pd.DataFrame({"reales":y_val,"prediccion":resultados})
validacion['indice'] = range(0,20)
#validacion.plot.scatter(x="indice)
ax1 = validacion.plot(kind="scatter",x="indice",y="reales", color="g",label="Reales")
validacion.plot(kind="scatter",x="indice",y="prediccion", ax=ax1, color="r",label="Predicciones")
plt.title('validate')
# Out:
# Text(0.5, 1.0, 'validate')

# %%
validate_loss = pd.DataFrame({"loss":history.history['loss'],"val_loss":history.history['val_loss']})
validate_loss.plot()
plt.title("Validate loss")
# Out:
# Text(0.5, 1.0, 'Validate loss')

# %%
compara = pd.DataFrame(np.array([y_val, [x[0] for x in results]])).transpose()
compara.columns = ['real', 'prediccion']

inverted = scaler.inverse_transform(compara.values)

compara2 = pd.DataFrame(inverted)
compara2.columns = ['real', 'prediccion']
compara2['diferencia'] = abs(compara2['real'] - compara2['prediccion'])
compara2.head()
# Out:
#        real  prediccion  diferencia
# 0  0.105042    0.092245    0.012796
# 1  0.100542    0.092245    0.008296
# 2  0.093750    0.092245    0.001505
# 3  0.089833    0.092245    0.002412
# 4  0.093167    0.092245    0.000921

# %%
compara2.describe()
# Out:
#             real  prediccion  diferencia
# count  20.000000   20.000000   20.000000
# mean    0.087167    0.092245    0.009920
# std     0.010830    0.000000    0.006392
# min     0.073875    0.092245    0.000921
# 25%     0.074854    0.092245    0.004683
# 50%     0.087750    0.092245    0.009271
# 75%     0.095177    0.092245    0.017391
# max     0.105042    0.092245    0.018370

# %%
comparacion_predicciones = pd.DataFrame({"real":compara2['real'],"prediccion":compara2['prediccion']})
comparacion_predicciones.plot()
plt.title("Comparación predicciones")
# Out:
# Text(0.5, 1.0, 'Comparación predicciones')

# %%
plt.title('Accuracy')
plt.plot(history.history['mean_squared_error'])
plt.show()

# %%
model.save('escenario_3.h5')
